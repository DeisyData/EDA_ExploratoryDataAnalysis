# %% [markdown]
# <a href="https://colab.research.google.com/github/DeisyData/EDA_ExploratoryDataAnalysis/blob/main/Explorador_HeatMap_Corr_VarAmb_VarElec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import statsmodels.graphics.gofplots as sm
from sklearn.preprocessing import PowerTransformer

# %%
turbina_df = pd.read_excel('/content/datos turbina.xlsx')
turbina_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 11 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Dia                             54 non-null     datetime64[ns]
#  1   Temperatura Diaria Promedio
# oC  54 non-null     float64
#  2   Humedad
# %                      54 non-null     int64
#  3   Precipitación
# mm                54 non-null     float64
#  4   Caudal m3/s                     54 non-null     float64
#  5   RPM                             54 non-null     float64
#  6   Voltaje G1                      54 non-null     float64
#  7   Voltaje G2                      54 non-null     float64
#  8   Voltaje R1                      54 non-null     float64
#  9   Voltaje R2                      54 non-null     float64
#  10  Potencia Generada
# w/h           54 non-null     float64
# dtypes: datetime64[ns](1), float64(9), int64(1)
# ...

# %%
sns.set(rc={'figure.figsize':(10,10)})
corr_matriz = turbina_df.corr().round(2)
sns.heatmap(data=corr_matriz, annot = True)
# Out:
# <Axes: >
